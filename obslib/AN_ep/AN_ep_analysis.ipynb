# %%
import sys
import os
import numpy as np
import pandas as pd
import pylab as py
import matplotlib.pyplot as plt
from  matplotlib import rc
from matplotlib.colors import LogNorm
# %matplotlib inline
from tools.tools import save,load,lprint
from tools.config import load_config, conf
from fitlab.resman import RESMAN
from fitlab.parman import PARMAN
from AN_theory0 import get_AN as ANthy
from AN_theory0 import get_ANfrag as ANfragthy
from AN_theory0 import get_ANQS as ANQSthy

# %%
load_config('input_ep.py')
conf['resman']=RESMAN()
conf['parman']=PARMAN()
conf['resman'].get_residuals(conf['parman'].par);
# Out:
# loading ANep data sets 2001

# %%
df = pd.read_excel("/Users/pitonyak/GIT/jam3d/database/AN_ep/expdata/1000.xlsx")
dfcut = df.query('pT > 1')
df2 = pd.read_excel("/Users/pitonyak/GIT/jam3d/database/AN_ep/expdata/1001.xlsx")
df3 = pd.read_excel("/Users/pitonyak/GIT/jam3d/database/AN_ep/expdata/2000.xlsx")
df3cut = df3.query('pT > 1')
df4 = pd.read_excel("/Users/pitonyak/GIT/jam3d/database/AN_ep/expdata/2001.xlsx")

# %%
fig = plt.figure()

plt.figure(figsize=(10,10))

pT = 1.0
rs = 7.25
had = 'pi+'
tar = 'p'
xF = np.arange(0.0, 0.8, 0.05)

AN = [ANthy(-x, pT, rs, tar, had) for x in xF]
ANfrag = [ANfragthy(-x, pT, rs, tar, had) for x in xF]
ANQS = [ANQSthy(-x, pT, rs, tar, had) for x in xF]

ax1 = plt.subplot(2, 2, 1)
ax1.plot(xF, AN)
ax1.plot(xF, ANfrag, linestyle = 'dashed')
ax1.plot(xF, ANQS, linestyle = 'dashdot')
plt.errorbar(df4['xF'], df4['value'], df4['alpha'], fmt='o')
ax1.set(xlabel = '$x_F$', ylabel = '$A_N$', title = 'HERMES, $\\pi^+$')
plt.ylim((-0.1, 0.2))

pT = 1.0
rs = 7.25
had = 'pi-'
tar = 'p'
xF = np.arange(0.0, 0.8, 0.05)

AN = [ANthy(-x, pT, rs, tar, had) for x in xF]
ANfrag = [ANfragthy(-x, pT, rs, tar, had) for x in xF]
ANQS = [ANQSthy(-x, pT, rs, tar, had) for x in xF]

ax2 = plt.subplot(2, 2, 2)
ax2.plot(xF, AN, label = '$A_N$')
ax2.plot(xF, ANfrag, linestyle = 'dashed', label = '$A_N^H$')
ax2.plot(xF, ANQS, linestyle = 'dashdot', label = '$A_N^F$')
ax2.errorbar(df2['xF'], df2['value'], df2['alpha'], fmt='o', label = 'Experimental $A_N$')
ax2.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax2.set(xlabel = '$x_F$', ylabel = '$A_N$', title = 'HERMES, $\\pi^-$')
plt.ylim((-0.1, 0.2))

xF = 0.15
rs = 7.25
had = 'pi+'
tar = 'p'
pT = np.arange(1, 2, 0.05)

AN = [ANthy(-xF, p, rs, tar, had) for p in pT]
ANfrag = [ANfragthy(-xF, p, rs, tar, had) for p in pT]
ANQS = [ANQSthy(-xF, p, rs, tar, had) for p in pT]

ax3 = plt.subplot(2, 2, 3)
ax3.plot(pT, AN)
ax3.plot(pT, ANfrag, linestyle = 'dashed')
ax3.plot(pT, ANQS, linestyle = 'dashdot')
ax3.errorbar(df3cut['pT'], df3cut['value'], df3cut['alpha'], fmt='o')
ax3.set(xlabel = '$P_T$', ylabel = '$A_N$', title = 'HERMES, $\\pi^+$')
plt.ylim((-0.1, 0.1))

xF = 0.15
rs = 7.25
had = 'pi-'
tar = 'p'
pT = np.arange(1, 2, 0.05)

AN = [ANthy(-xF, p, rs, tar, had) for p in pT]
ANfrag = [ANfragthy(-xF, p, rs, tar, had) for p in pT]
ANQS = [ANQSthy(-xF, p, rs, tar, had) for p in pT]

ax4 = plt.subplot(2, 2, 4)
ax4.plot(pT, AN)
ax4.plot(pT, ANfrag, linestyle = 'dashed')
ax4.plot(pT, ANQS, linestyle = 'dashdot')
ax4.errorbar(dfcut['pT'], dfcut['value'], dfcut['alpha'], fmt='o')
ax4.set(xlabel = '$P_T$', ylabel = '$A_N$', title = 'HERMES, $\\pi^-$')
plt.ylim((-0.3, 0.1))


plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

pT = 1.0
rs = 4.6
had = 'pi+'
tar = 'n'
xF = np.arange(0, 0.8, 0.05)

AN = [ANthy(-x, pT, rs, tar, had) for x in xF]
ANfrag = [ANfragthy(-x, pT, rs, tar, had) for x in xF]
ANQS = [ANQSthy(-x, pT, rs, tar, had) for x in xF]

ax5 = plt.subplot(2, 2, 1)
ax5.plot(xF, AN)
ax5.plot(xF, ANfrag, linestyle = 'dashed')
ax5.plot(xF, ANQS, linestyle = 'dashdot')
ax5.set(xlabel = '$x_F$', ylabel = '$A_N$', title = 'JLab-12, $\\pi^+$')

pT = 1.0
rs = 4.6
had = 'pi-'
tar = 'n'
xF = np.arange(0, 0.8, 0.05)

AN = [ANthy(-x, pT, rs, tar, had) for x in xF]
ANfrag = [ANfragthy(-x, pT, rs, tar, had) for x in xF]
ANQS = [ANQSthy(-x, pT, rs, tar, had) for x in xF]

ax6 = plt.subplot(2, 2, 2)
ax6.plot(xF, AN, label = '$A_N$')
ax6.plot(xF, ANfrag, linestyle = 'dashed', label = '$A_N^H$')
ax6.plot(xF, ANQS, linestyle = 'dashdot', label = '$A_N^F$')
ax6.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax6.set(xlabel = '$x_F$', ylabel = '$A_N$', title = 'JLab-12, $\\pi^-$')

xF = 0.26
rs = 4.6
had = 'pi+'
tar = 'n'
pT = np.arange(1, 2, 0.05)

AN = [ANthy(-xF, p, rs, tar, had) for p in pT]
ANfrag = [ANfragthy(-xF, p, rs, tar, had) for p in pT]
ANQS = [ANQSthy(-xF, p, rs, tar, had) for p in pT]

ax7 = plt.subplot(2, 2, 3)
ax7.plot(pT, AN)
ax7.plot(pT, ANfrag, linestyle = 'dashed')
ax7.plot(pT, ANQS, linestyle = 'dashdot')
ax7.set(xlabel = '$P_T$', ylabel = '$A_N$', title = 'JLab-12, $\\pi^+$')

xF = 0.26
rs = 4.6
had = 'pi-'
tar = 'n'
pT = np.arange(1, 2, 0.05)

AN = [ANthy(-xF, p, rs, tar, had) for p in pT]
ANfrag = [ANfragthy(-xF, p, rs, tar, had) for p in pT]
ANQS = [ANQSthy(-xF, p, rs, tar, had) for p in pT]

ax8 = plt.subplot(2, 2, 4)
ax8.plot(pT, AN)
ax8.plot(pT, ANfrag, linestyle = 'dashed')
ax8.plot(pT, ANQS, linestyle = 'dashdot')
ax8.set(xlabel = '$P_T$', ylabel = '$A_N$', title = 'JLab-12, $\\pi^-$')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure()

plt.figure(figsize=(15,5))

pT = 3.0
rs = 63.0
had = 'pi+'
tar = 'p'
xF = np.arange(0.0, 0.8, 0.05)

AN = [ANthy(x, pT, rs, tar, had) for x in xF]
ANfrag = [ANfragthy(x, pT, rs, tar, had) for x in xF]
ANQS = [ANQSthy(x, pT, rs, tar, had) for x in xF]

ax9 = plt.subplot(1, 3, 1)
ax9.plot(xF, AN)
ax9.plot(xF, ANfrag, linestyle = 'dashed')
ax9.plot(xF, ANQS, linestyle = 'dashdot')
ax9.set(xlabel = '$x_F$', ylabel = '$A_N$', title = 'EIC, $\\pi^+$')

pT = 3.0
rs = 63.0
had = 'pi-'
tar = 'p'
xF = np.arange(0.0, 0.8, 0.05)

AN = [ANthy(x, pT, rs, tar, had) for x in xF]
ANfrag = [ANfragthy(x, pT, rs, tar, had) for x in xF]
ANQS = [ANQSthy(x, pT, rs, tar, had) for x in xF]

ax10 = plt.subplot(1, 3, 2)
ax10.plot(xF, AN)
ax10.plot(xF, ANfrag, linestyle = 'dashed')
ax10.plot(xF, ANQS, linestyle = 'dashdot')
ax10.set(xlabel = '$x_F$', ylabel = '$A_N$', title = 'EIC, $\\pi^-$')

pT = 3.0
rs = 63.0
had = 'pi0'
tar = 'p'
xF = np.arange(0.0, 0.8, 0.05)

AN = [ANthy(x, pT, rs, tar, had) for x in xF]
ANfrag = [ANfragthy(x, pT, rs, tar, had) for x in xF]
ANQS = [ANQSthy(x, pT, rs, tar, had) for x in xF]

ax11 = plt.subplot(1, 3, 3)
ax11.plot(xF, AN, label = '$A_N$')
ax11.plot(xF, ANfrag, linestyle = 'dashed', label = '$A_N^H$')
ax11.plot(xF, ANQS, linestyle = 'dashdot', label = '$A_N^F$')
ax11.set(xlabel = '$x_F$', ylabel = '$A_N$', title = 'EIC, $\\pi^0$')
ax11.legend(bbox_to_anchor=(1.05, 1), loc = 2, borderaxespad=0.)

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))

pT = 2.0
rs = 17.3
had = 'pi+'
tar = 'p'
xF = np.arange(0.0, 0.8, 0.05)

AN = [ANthy(-x, pT, rs, tar, had) for x in xF]
ANfrag = [ANfragthy(-x, pT, rs, tar, had) for x in xF]
ANQS = [ANQSthy(-x, pT, rs, tar, had) for x in xF]

ax12 = plt.subplot(1, 2, 1)
ax12.plot(xF, AN)
ax12.plot(xF, ANfrag, linestyle = 'dashed')
ax12.plot(xF, ANQS, linestyle = 'dashdot')
ax12.set(xlabel = '$x_F$', ylabel = '$A_N$', title = 'COMPASS, $\\pi^+$')

pT = 2.0
rs = 17.3
had = 'pi-'
tar = 'p'
xF = np.arange(0.0, 0.8, 0.05)

AN = [ANthy(-x, pT, rs, tar, had) for x in xF]
ANfrag = [ANfragthy(-x, pT, rs, tar, had) for x in xF]
ANQS = [ANQSthy(-x, pT, rs, tar, had) for x in xF]

ax13 = plt.subplot(1, 2, 2)
ax13.plot(xF, AN, label = '$A_N$')
ax13.plot(xF, ANfrag, linestyle = 'dashed', label = '$A_N^H$')
ax13.plot(xF, ANQS, linestyle = 'dashdot', label = '$A_N^F$')
ax13.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax13.set(xlabel = '$x_F$', ylabel = '$A_N$', title = 'COMPASS, $\\pi^-$')

plt.tight_layout()
plt.show()
